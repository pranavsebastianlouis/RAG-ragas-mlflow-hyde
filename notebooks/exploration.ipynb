# %%
from langchain_community.document_loaders import PyPDFLoader
from langchain_huggingface import HuggingFaceEmbeddings

# %%
PDF_PATH = r"D:\Projects\debyez\data\raw\TH Delhi 07-12-2025.pdf"

# %%
#loading pdf
documents = []
loader  = PyPDFLoader(PDF_PATH)
docs = loader.load()
documents.extend(docs) #if we have multiple pdfs
print(f"Loaded {len(documents)} pages from PDF")
# Out:
# Loaded 20 pages from PDF

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
# Split documents into smaller chunks for better retrieval
# chunk_size: Maximum size of each chunk (in characters)
# chunk_overlap: Overlap between chunks to maintain context
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=512, 
    chunk_overlap=100
)
splits = text_splitter.split_documents(documents)
print(f"Splitt into {len(splits)} chunks")
# Out:
# Splitt into 546 chunks

# %%
#model to do embeddings
#selected the embedding model BAAI/bge-base-en-v1.5
# from sentence_transformers import SentenceTransformer
# model = SentenceTransformer("BAAI/bge-base-en-v1.5")
embeddings = HuggingFaceEmbeddings(model_name = "BAAI/bge-base-en-v1.5")
print("Embedding models loaded")
# Out:
# Embedding models loaded

# %% [raw]
# docker run -d -p 8080:8080 -p 50051:50051 \
#   -e AUTHENTICATION_ANONYMOUS_ACCESS_ENABLED=true \
#   -e DEFAULT_VECTORIZER_MODULE=none \
#   -e PERSISTENCE_DATA_PATH=/var/lib/weaviate \
#   -v ${PWD}/weaviate_data:/var/lib/weaviate \
#   semitechnologies/weaviate

# %%
import weaviate
with weaviate.connect_to_local() as client: 
    print(client.is_ready())
client.close()
# Out:
# True

# %%
print(client)
# Out:
# <weaviate.client.WeaviateClient object at 0x0000017127757F90>

# %%
from langchain_weaviate import WeaviateVectorStore
client.connect()
db = WeaviateVectorStore.from_documents(splits, embeddings, client=client, index_name="Newspaperchunks")

# %%
print(db)
# Out:
# <langchain_weaviate.vectorstores.WeaviateVectorStore object at 0x0000017175C7D9D0>

# %%
client.collections.exists("Newspaperchunks")# checking if table exists
# Out:
# True

# %%
collections = client.collections.list_all()
for c in collections:
    print(c)# listing all tables in the db
# Out:
# Newspaperchunks

# %%
collections = client.collections.get("Newspaperchunks")# handle to the table we can use to do query and modify data

# %%
response = collections.aggregate.over_all(total_count=True)
print(response) # number of rows that exist in the db
# Out:
# AggregateReturn(properties={}, total_count=1638)

# %%
collections.query.fetch_objects(limit = 10)#like fetching the first 10 rows
# Out:
# QueryReturn(objects=[Object(uuid=_WeaviateUUIDInt('008992fa-7b61-460f-a185-36d1e30c79f1'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'page': 13.0, 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'source': 'D:\\Projects\\debyez\\data\\raw\\TH Delhi 07-12-2025.pdf', 'total_pages': 20.0, 'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib); modified using iText® 5.5.13 ©2000-2018 iText Group NV (AGPL-version)', 'moddate': datetime.datetime(2025, 12, 7, 7, 13, 45, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))), 'page_label': '14', 'text': 'this data oﬀers little comfort for the future.\nIndia’s manufacturing Purchasing Managers’\nIndex (PMI) has fallen to a nine-month low, and\nthe new export orders sub-index has slipped to a\n13-month low, suggesting the worst of the tariﬀ\npain may be yet to come.\nImports surging\nWhile falling exports are a concern, a massive\nsurge in precious metal imports have also played\na role in the depreciation of the rupee.\nIn September and October, Indian purchases\nsurged. Data shows that gold imports', 'creationdate': datetime.datetime(2025, 12, 6, 23, 52, 45, tzinfo=datetime.timezone.utc)}, references=None, vector={}, collection='Newspaperchunks'), Object(uuid=_WeaviateUUIDInt('00dc6fc0-b283-4547-861a-0be370c02605'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'page': 18.0, 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'source': 'D:\\Projects\\debyez\\data\\raw\\TH Delhi 07-12-2025.pdf', 'total_pages': 20.0, 'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib); modified using iText® 5.5.13 ©2000-2018 iText Group NV (AGPL-version)', 'moddate': datetime.datetime(2025, 12, 7, 7, 13, 45, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))), 'page_label': '19', 'text': 'ravaged by the catastrophe. \n(Text by Meera Srinivasan)\nAn island ravaged \nby a cyclone\nWith 22 of its 25 districts devastated and 611 lives lost, torrential rain from Cyclone Ditwah has left Sri Lanka reeling; the UN has /f_lagged a high risk of food insecurity, severe\ncrop damage, and widespread destruction of infrastructure; India and other countries have stepped in to help, but the island nation’s recovery will be a gruelling one \nY\nPrecious cargo:People carrying pets and other', 'creationdate': datetime.datetime(2025, 12, 6, 23, 52, 45, tzinfo=datetime.timezone.utc)}, references=None, vector={}, collection='Newspaperchunks'), Object(uuid=_WeaviateUUIDInt('00ddf441-8e6b-41d6-9fa4-a495c830316e'), metadata=MetadataReturn(creation_time=None, last_update_time=None, distance=None, certainty=None, score=None, explain_score=None, is_consistent=None, rerank_score=None), properties={'page': 1.0, 'creator': 'pdf-lib (https://github.com/Hopding/pdf-lib)', 'source': 'D:\\Projects\\debyez\\data\\raw\\TH Delhi 07-12-2025.pdf', 'total_pages': 20.0, 'producer': 'pdf-lib (https://github.com/Hopding/pdf-lib); modified using iText® 5.5.13 ©2000-2018 iText Group NV (AGPL-version)', 'moddate': datetime.datetime(2025, 12, 7, 7, 13, 45, tzinfo=datetime.timezone(datetime.timedelta(seconds=19800))), 'text': 'Road.\nAnother message issued a simi-\nlar threat to the DUJ oﬃce at F-29,\nShankar Market in the Connaught\nPlace area.\nMultiple police teams, accompa-\nnied by the bomb disposal unit,\ndog squads, and /f_ire tenders,\nrushed to the locations and con-\nducted extensive checks. The areas\nwere cordoned oﬀ and access was\nrestricted as security agencies car-\nried out a sweep of the premises.\n“Nothing suspicious was found\nat both locations. After thorough\ninspection, both threats were de-', 'page_label': '2', 'creationdate': datetime.datetime(2025, 12, 6, 23, 52, 45, tzinfo=datetime.timezone.utc)}, references=None, ...

# %%
import pandas as pd

# Get the collection we have collections handle
# Fetch rows
response = collections.query.fetch_objects(limit=50)

rows = []

for obj in response.objects:
    row = {"id": obj.uuid, **obj.properties,}        # text, source, page, etc each  propertie becomes a column
    rows.append(row)
# Convert to DataFrame
df = pd.DataFrame(rows)

df
# Out:
#                                       id  page  \
# 0   008992fa-7b61-460f-a185-36d1e30c79f1  13.0
# 1   00dc6fc0-b283-4547-861a-0be370c02605  18.0
# 2   00ddf441-8e6b-41d6-9fa4-a495c830316e   1.0
# 3   010429b6-5728-45fe-9e48-43bda50a55dd   7.0
# 4   0123b0d9-d701-44c3-be0e-30524ce8dea0  13.0
# 5   016fbd03-f367-435b-8ade-67ab1ec4421d   8.0
# 6   017159a8-c795-403f-806a-836e8d2f18e6   7.0
# 7   01b4e5c4-6c9e-4edf-9fc9-c42e8d7260ff  13.0
# 8   01d5ade1-4bcb-49d5-a5df-298888d4c19c   3.0
# 9   01f048bb-93f1-4173-9461-cb1c33816aa8  14.0
# 10  021a2ab8-6c3a-471d-864d-8dc890176940   3.0
# 7   pdf-lib (https://github.com/Hopding/pdf-lib)
# 8   pdf-lib (https://github.com/Hopding/pdf-lib)
# 9   pdf-lib (https://github.com/Hopding/pdf-lib)
# 10  pdf-lib (https://github.com/Hopding/pdf-lib)
# 11  pdf-lib (https://github.com/Hopding/pdf-lib)
# 12  pdf-lib (https://github.com/Hopding/pdf-lib)
# 13  pdf-lib (https://github.com/Hopding/pdf-lib)
# 14  pdf-lib (https://github.com/Hopding/pdf-lib)
# 15  pdf-lib (https://github.com/Hopding/pdf-lib)
# 16  pdf-lib (https://github.com/Hopding/pdf-lib)
# 17  pdf-lib (https://github.com/Hopding/pdf-lib)
# 18  pdf-lib (https://github.com/Hopding/pdf-lib)
# 19  pdf-lib (https://github.com/Hopding/pdf-lib)
# 20  pdf-lib (https://github.com/Hopding/pdf-lib)
# 21  pdf-lib (https://github.com/Hopding/pdf-lib)
# 22  pdf-lib (https://github.com/Hopding/pdf-lib)
# 23  pdf-lib (https://github.com/Hopding/pdf-lib)
# 24  pdf-lib (https://github.com/Hopding/pdf-lib)
# 25  pdf-lib (https://github.com/Hopding/pdf-lib)
# 26  pdf-lib (https://github.com/Hopding/pdf-lib)
# 27  pdf-lib (https://github.com/Hopding/pdf-lib)
# 28  pdf-lib (https://github.com/Hopding/pdf-lib)
# 29  pdf-lib (https://github.com/Hopding/pdf-lib)
# 30  pdf-lib (https://github.com/Hopding/pdf-lib)
# 31  pdf-lib (https://github.com/Hopding/pdf-lib)
# 32  pdf-lib (https://github.com/Hopding/pdf-lib)
# 33  pdf-lib (https://github.com/Hopding/pdf-lib)
# 34  pdf-lib (https://github.com/Hopding/pdf-lib)
# 35  pdf-lib (https://github.com/Hopding/pdf-lib)
# 36  pdf-lib (https://github.com/Hopding/pdf-lib)
# 37  pdf-lib (https://github.com/Hopding/pdf-lib)
# 38  pdf-lib (https://github.com/Hopding/pdf-lib)
# 39  pdf-lib (https://github.com/Hopding/pdf-lib)
# 40  pdf-lib (https://github.com/Hopding/pdf-lib)
# 41  pdf-lib (https://github.com/Hopding/pdf-lib)
# 42  pdf-lib (https://github.com/Hopding/pdf-lib)
# 43  pdf-lib (https://github.com/Hopding/pdf-lib)
# 44  pdf-lib (https://github.com/Hopding/pdf-lib)
# 45  pdf-lib (https://github.com/Hopding/pdf-lib)
# 46  pdf-lib (https://github.com/Hopding/pdf-lib)
# 47  pdf-lib (https://github.com/Hopding/pdf-lib)
# 48  pdf-lib (https://github.com/Hopding/pdf-lib)
# 49  pdf-lib (https://github.com/Hopding/pdf-lib)
#
#                                                source  total_pages  \
# 0   D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 1   D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 2   D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 3   D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 4   D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 5   D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 6   D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 7   D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 8   D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 9   D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 10  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 11  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 12  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 13  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 14  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 15  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 16  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 17  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 18  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 19  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 20  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 21  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 22  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 23  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 24  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 25  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 26  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 27  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 28  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 29  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 30  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 31  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 32  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 33  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 34  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 35  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 36  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 37  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 38  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 39  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 40  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 41  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 42  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 43  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 44  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 45  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 46  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 47  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 48  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 49  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
#
#                                              producer  \
# 0   pdf-lib (https://github.com/Hopding/pdf-lib); ...
#
# 9   Altman, who previously exulted in his\n/f_irst...         15
# 10  moved to low-concentra-\ntion and far-oﬀ areas...          4
# 11  TRAIN OF THOUGHTS\nK.R. DEEPAK\nX\nLosing Quin...         17
# 12  did not respond.\nA former DUSIB oﬃcial\nsaid ...          4
# 13  return, their tears have not\nbeen wiped away ...         10
# 14  expedite the formalities in-\nvolved in sendin...          8
# 15  tles into three groups with\na distinct carbon...         13
# 16  tions about how CEBAMA\nwill evolve over centu...         13
# 17  ( JMM)-Congress govern-\nment, led by Chief Mi...          9
# 18  dency at its root, not by\n/f_ighting dopamine...         13
# 19  research and theological investigation “exclud...         16
# 20  There’s something\nin the Mumbai air\nEven as ...          7
# 21  ter Navinchandra Ramgoo-\nlam and New Zealand\...         10
# 22  among investors. \n“Media coverage and in-\nst...         12
# 23  separate” and the latest\nclash would have “no...         16
# 24  are a referendum on the\nState government.\nFo...          8
# 25  A ND-NDECM\nYK\nTHE HINDU \n10 Sunday, Decembe...         10
# 26  Jewellery Business, Construction,\nChennai, Se...          6
# 27  scale operational failures\nindicate signi/f_i...         10
# 28  Monday. The anticipatory\nbail plea was moved ...          8
# 29  20 (29b, 2x4), Lungi Ngidi lbw b\nKuldeep 1 (1...         17
# 30  proximately 100 faculty members”,\nsuggesting ...          2
# 31  Castes Tamil,Telugu.Ct: 7382620365\nBRIDE WANT...          6
# 32  Y\nPrecious cargo:People carrying pets and oth...         19
# 33  tion and will continue to\nplay a supportive r...         11
# 34  identi/f_ied as “high-preva-\nlence areas” in ...         11
# 35  The Trinamool Con-\ngress leadership organised...          9
# 36  er, a victory oﬀers so much\nmore — an AFC Cha...         18
# 37  India’s recognition of\nBangladesh came 10\nda...         11
# 38  found that these sites had similar or higher y...         13
# 39  was little stopping him. He\ntook apart Prasid...         17
# 40  eastern India is expected\nto rise sharply by ...         12
# 41  neer TCS Chennai seeks well educa-\nted workin...          6
# 42  TRAIN OF THOUGHTS\nK.R. DEEPAK\nX\nLosing Quin...         17
# 43  A ND-NDECM\nYK\nTHE HINDU \n6\nSunday, Decembe...          6
# 44  sive. At the start of the year,\nit felt like ...         18
# 45  and shelling at a\nmajor Pakistan-Afghanis-\nt...         16
# 46  traditional ties with Russia, while ensuring t...         14
# 47  /f_ine of /uni20B910,000 for their\n/f_irst oﬀ...          9
# 48  morial in Alipur. \nDuring a discussion on the...          2
# 49  compatible groom. Any location.\nCaste/lang. n...          6
#
#                 creationdate
# 0  2025-12-06 23:52:45+00:00
# 1  2025-12-06 23:52:45+00:00
# 2  2025-12-06 23:52:45+00:00
# 3  2025-12-06 23:52:45+00:00
# 4  2025-12-06 23:52:45+00:00
# 5  2025-12-06 23:52:45+00:00
# 6  2025-12-06 23:52:45+00:00
# 7  2025-12-06 23:52:45+00:00
# 8  2025-12-06 23:52:45+00:00
# 9  2025-12-06 23:52:45+00:00
# 10 2025-12-06 23:52:45+00:00
# 11 2025-12-06 23:52:45+00:00
# 12 2025-12-06 23:52:45+00:00
# 13 2025-12-06 23:52:45+00:00
# 14 2025-12-06 23:52:45+00:00
# 15 2025-12-06 23:52:45+00:00
# 16 2025-12-06 23:52:45+00:00
# 17 2025-12-06 23:52:45+00:00
# 18 2025-12-06 23:52:45+00:00
# 19 2025-12-06 23:52:45+00:00
# 20 2025-12-06 23:52:45+00:00
# 21 2025-12-06 23:52:45+00:00
# 22 2025-12-06 23:52:45+00:00
# 23 2025-12-06 23:52:45+00:00
# 24 2025-12-06 23:52:45+00:00
# 25 2025-12-06 23:52:45+00:00
# 26 2025-12-06 23:52:45+00:00
# 27 2025-12-06 23:52:45+00:00
# 28 2025-12-06 23:52:45+00:00
# 29 2025-12-06 23:52:45+00:00
# 30 2025-12-06 23:52:45+00:00
# 31 2025-12-06 23:52:45+00:00
# 32 2025-12-06 23:52:45+00:00
# 33 2025-12-06 23:52:45+00:00
# 34 2025-12-06 23:52:45+00:00
# 35 2025-12-06 23:52:45+00:00
# 36 2025-12-06 23:52:45+00:00
# 37 2025-12-06 23:52:45+00:00
# 38 2025-12-06 23:52:45+00:00
# 39 2025-12-06 23:52:45+00:00
# 40 2025-12-06 23:52:45+00:00
# 41 2025-12-06 23:52:45+00:00
# 42 2025-12-06 23:52:45+00:00
# 43 2025-12-06 23:52:45+00:00
# 44 2025-12-06 23:52:45+00:00
# 45 2025-12-06 23:52:45+00:00
# 46 2025-12-06 23:52:45+00:00
# 47 2025-12-06 23:52:45+00:00
# 48 2025-12-06 23:52:45+00:00
# 49 2025-12-06 23:52:45+00:00

# %%
#retrival phase
query = "Give me news related to Indigo and airline industry?"
query_vector = embeddings.embed_query(query) #embedding the query

# %%
# print(query_vector)

# %%
response = collections.query.near_vector(near_vector = query_vector, limit = 5, 
                                        return_metadata =["distance", "score"] )

# %%
response

# %%
rows = []
for obj in response.objects:
    row = {
        "uuid": obj.uuid, "distance": obj.metadata.distance, **obj.properties #lower the distance the better
    }
    rows.append(row)
df = pd.DataFrame(rows)

df # the responses we got from the db
# Out:
#                                    uuid  distance  page  \
# 0  60410cd8-dadc-4da5-a64e-d043d17b18f0  0.287088   0.0
# 1  26cb80dd-c5c8-4abb-89c6-73d4eee4e30c  0.287088   0.0
# 2  91f089e0-b53d-4f89-90aa-64a5e349bd5a  0.287088   0.0
# 3  fdaaa309-62a4-4b1d-93c9-8feda7f9cc7c  0.292311   0.0
# 4  e0910367-cebd-4f7f-9552-1df3f2d5d519  0.292311   0.0
#
#                                         creator  \
# 0  pdf-lib (https://github.com/Hopding/pdf-lib)
# 1  pdf-lib (https://github.com/Hopding/pdf-lib)
# 2  pdf-lib (https://github.com/Hopding/pdf-lib)
# 3  pdf-lib (https://github.com/Hopding/pdf-lib)
# 4  pdf-lib (https://github.com/Hopding/pdf-lib)
#
#                                               source  total_pages  \
# 0  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 1  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 2  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 3  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
# 4  D:\Projects\debyez\data\raw\TH Delhi 07-12-202...         20.0
#
#                                             producer  \
# 0  pdf-lib (https://github.com/Hopding/pdf-lib); ...
# 1  pdf-lib (https://github.com/Hopding/pdf-lib); ...
# 2  pdf-lib (https://github.com/Hopding/pdf-lib); ...
# 3  pdf-lib (https://github.com/Hopding/pdf-lib); ...
# 4  pdf-lib (https://github.com/Hopding/pdf-lib); ...
#
#                     moddate  \
# 0 2025-12-07 07:13:45+05:30
# 1 2025-12-07 07:13:45+05:30
# 2 2025-12-07 07:13:45+05:30
# 3 2025-12-07 07:13:45+05:30
# 4 2025-12-07 07:13:45+05:30
#
#                                                 text page_label  \
# 0  compared with 700 on Fri-\nday. Normalcy is ex...          1
# 1  compared with 700 on Fri-\nday. Normalcy is ex...          1
# 2  compared with 700 on Fri-\nday. Normalcy is ex...          1
# 3  Vol. 15 /L50539No. 49\nRegd. DL(ND)-11/6110/20...          1
# 4  Vol. 15 /L50539No. 49\nRegd. DL(ND)-11/6110/20...          1
#
#                creationdate
# 0 2025-12-06 23:52:45+00:00
# 1 2025-12-06 23:52:45+00:00
# 2 2025-12-06 23:52:45+00:00
# 3 2025-12-06 23:52:45+00:00
# 4 2025-12-06 23:52:45+00:00

# %%
# for val in client.collections.list_all():
#     client.collections.delete(val)

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
#building a query system with history
context_q_sys_prompt = (
    """Given a chat history and the latest user question 
    which might reference context in the chat history, formulate a standalone 
    question which can be understood without the chat history. Do NOT answer the 
    question, just reformulate if required and otherwise return as is."""
)
context_prompt = ChatPromptTemplate.from_messages([
    ("system", context_q_sys_prompt), MessagesPlaceholder("chat_history"), ("human", "{input}")])
#we include the system prompt whcih takes the earlier context and converts the human input into a meaningful question based
#on the earlier questions by user.

# %%
from langchain_classic.chains import create_history_aware_retriever, create_retrieval_chain

# %%
from langchain_ollama import OllamaLLM
llm = OllamaLLM(model="mistral", temperature=0,) # initialize mistral as llm

# %%
retriever = db.as_retriever() # our retriever

# %%
history_aware_retriever = create_history_aware_retriever(
    llm, retriever, context_prompt
)   # running vector retrieval on the rewritten query.

# %%
#now we take the retrieved content and generate the answer
sys_prompt = (
    """You are an assistant for question-answering-tasks.
    Use the following peices of retrieved context to answer the question.
    If you don't know the answer, say that you don't know. Keep the answer concise.\n\n {context}"""
)
qa_prompt = ChatPromptTemplate.from_messages([
    ("system", sys_prompt), MessagesPlaceholder("chat_history"), ("human", "{input}")])

# %%
# Import all required libraries
from langchain_classic.chains import create_history_aware_retriever, create_retrieval_chain
from langchain_classic.chains.combine_documents import create_stuff_documents_chain
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain_core.chat_history import BaseChatMessageHistory
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.runnables.history import RunnableWithMessageHistory

# %%
# Dictionary to store chat histories for different sessions
# In Jupyter, this persists for the entire notebook session
store = {}

def get_session_history(session_id: str) -> BaseChatMessageHistory:
    """
    Retrieves or creates a chat history for a given session.
    
    Args:
        session_id: Unique identifier for the conversation session
    
    Returns:
        ChatMessageHistory object containing the conversation history
    """
    if session_id not in store:
        store[session_id] = ChatMessageHistory()
    return store[session_id]

print("Session history management setup complete")
# Out:
# Session history management setup complete

# %%
# Create the question-answer chain
question_answer_chain = create_stuff_documents_chain(llm, qa_prompt)
print("QA chain created")
# Out:
# QA chain created

# %%
# Combine retrieval and QA into a single chain
rag_chain = create_retrieval_chain(
    history_aware_retriever, 
    question_answer_chain
)

# %%
def ask_question(question, session_id="default_session"):
    """
    Ask a question to the RAG chatbot.
    
    Args:
        question: Your question as a string
        session_id: Session identifier (use same ID to maintain conversation context)
    
    Returns:
        Dictionary containing the answer and other metadata
    """
    # Invoke the conversational RAG chain
    response = conv_rag_chain.invoke(
        {"input": question},
        config={"configurable": {"session_id": session_id}},
    )
    
    # Display the answer
    print(f"\n📝 Question: {question}")
    print(f"💡 Answer: {response['answer']}\n")
    
    # Optionally show the chat history
    session_history = get_session_history(session_id)
    print(f"📚 Total messages in history: {len(session_history.messages)}")
    
    return response

# %%
# Wrap the chain with message history management
conv_rag_chain = RunnableWithMessageHistory(
    rag_chain,
    get_session_history,
    input_messages_key="input",
    history_messages_key="chat_history",  # Fixed: was "chathistory"
    output_messages_key="answer"
)
print("Complete conversational RAG chain ready")
print("\n" + "="*60)
print("Setup complete! You can now ask questions.")
print("="*60 + "\n")
# Out:
# Complete conversational RAG chain ready
#
# ============================================================
# Setup complete! You can now ask questions.
# ============================================================

# %%
#install ollama and download mistral

# %%
# Now you can ask questions! Run this cell multiple times with different questions

#ask_question("What is the name of the newspaper")

#ask_question("Is there any info on the stock market?")

#ask_question("Summarize the editorial for me.")

#ask_question("Any news about the state of Kerala?")

#Checking context
ask_question("What was my last question?")
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[35], line 12
#       1 # Now you can ask questions! Run this cell multiple times with different questions
#       2
#       3 #ask_question("What is the name of the newspaper")
#    (...)     10
#      11 #Checking context
# ---> 12 ask_question("What was my last question?")
#
# Cell In[32], line 13, in ask_question(question, session_id)
#       2 """
#       3 Ask a question to the RAG chatbot.
#       4
#    (...)     10     Dictionary containing the answer and other metadata
#      11 """
#      12 # Invoke the conversational RAG chain
# ---> 13 response = conv_rag_chain.invoke(
#      14     {"input": question},
#      15     config={"configurable": {"session_id": session_id}},
#      16 )
#      18 # Display the answer
#      19 print(f"\n📝 Question: {question}")
#
# File d:\Projects\debyez\.venv\Lib\site-packages\langchain_core\runnables\base.py:5548, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5541 @override
#    5542 def invoke(
#    5543     self,
#    (...)   5546     **kwargs: Any | None,
#    5547 ) -> Output:
# -> 5548     return self.bound.invoke(
#    5549         input,
#    5550         self._merge_configs(config),
#    5551         **{**self.kwargs, **kwargs},
#    5552     )
#
# File d:\Projects\debyez\.venv\Lib\site-packages\langchain_core\runnables\base.py:5548, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5541 @override
#    5542 def invoke(
#    5543     self,
#    (...)   5546     **kwargs: Any | None,
#    5547 ) -> Output:
# -> 5548     return self.bound.invoke(
#    5549         input,
#    5550         self._merge_configs(config),
#    5551         **{**self.kwargs, **kwargs},
#    5552     )
#
# File d:\Projects\debyez\.venv\Lib\site-packages\langchain_core\runnables\base.py:3143, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3141                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3142             else:
# -> 3143                 input_ = context.run(step.invoke, input_, config)
#    3144 # finish the root run
#    3145 except BaseException as e:
#
# File d:\Projects\debyez\.venv\Lib\site-packages\langchain_core\runnables\base.py:5548, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5541 @override
#    5542 def invoke(
#    5543     self,
#    (...)   5546     **kwargs: Any | None,
#    5547 ) -> Output:
# -> 5548     return self.bound.invoke(
#    5549         input,
#    5550         self._merge_configs(config),
#    5551         **{**self.kwargs, **kwargs},
#    5552     )
#
# File d:\Projects\debyez\.venv\Lib\site-packages\langchain_core\runnables\base.py:4871, in RunnableLambda.invoke(self, input, config, **kwargs)
#    4856 """Invoke this `Runnable` synchronously.
#    4857
#    4858 Args:
#    (...)   4868
#    4869 """
#    4870 if hasattr(self, "func"):
# -> 4871     return self._call_with_config(
#    4872         self._invoke,
#    4873         input,
#    4874         ensure_config(config),
#    4875         **kwargs,
#    4876     )
#    4877 msg = "Cannot invoke a coroutine function synchronously.Use `ainvoke` instead."
#    4878 raise TypeError(msg)
#
# File d:\Projects\debyez\.venv\Lib\site-packages\langchain_core\runnables\base.py:2058, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    2054     child_config = patch_config(config, callbacks=run_manager.get_child())
#    2055     with set_config_context(child_config) as context:
#    2056         output = cast(
#    2057             "Output",
# -> 2058             context.run(
#    2059                 call_func_with_variable_args,  # type: ignore[arg-type]
#    2060                 func,
#    2061                 input_,
#    2062                 config,
#    2063                 run_manager,
#    2064                 **kwargs,
#    2065             ),
#    2066         )
#    2067 except BaseException as e:
#    2068     run_manager.on_chain_error(e)
#
# File d:\Projects\debyez\.venv\Lib\site-packages\langchain_core\runnables\config.py:433, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     431 if run_manager is not None and accepts_run_manager(func):
#     432     kwargs["run_manager"] = run_manager
# --> 433 return func(input, **kwargs)
#
# File d:\Projects\debyez\.venv\Lib\site-packages\langchain_core\runnables\base.py:4739, in RunnableLambda._invoke(self, input_, run_manager, config, **kwargs)
#    4735         msg = (
#    4736             f"Recursion limit reached when invoking {self} with input {input_}."
#    4737         )
#    4738         raise RecursionError(msg)
# -> 4739     output = output.invoke(
#    4740         input_,
#    4741         patch_config(
#    4742             config,
#    4743             callbacks=run_manager.get_child(),
#    4744             recursion_limit=recursion_limit - 1,
#    4745         ),
#    4746     )
#    4747 return cast("Output", output)
#
# File d:\Projects\debyez\.venv\Lib\site-packages\langchain_core\runnables\base.py:5548, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5541 @override
#    5542 def invoke(
#    5543     self,
#    (...)   5546     **kwargs: Any | None,
#    5547 ) -> Output:
# -> 5548     return self.bound.invoke(
#    5549         input,
#    5550         self._merge_configs(config),
#    5551         **{**self.kwargs, **kwargs},
#    5552     )
#
# File d:\Projects\debyez\.venv\Lib\site-packages\langchain_core\runnables\base.py:3143, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3141                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3142             else:
# -> 3143                 input_ = context.run(step.invoke, input_, config)
#    3144 # finish the root run
#    3145 except BaseException as e:
#
# File d:\Projects\debyez\.venv\Lib\site-packages\langchain_core\runnables\passthrough.py:507, in RunnableAssign.invoke(self, input, config, **kwargs)
#     500 @override
#     501 def invoke(
#     502     self,
#    (...)    505     **kwargs: Any,
#     506 ) -> dict[str, Any]:
# --> 507     return self._call_with_config(self._invoke, input, config, **kwargs)
#
# File d:\Projects\debyez\.venv\Lib\site-packages\langchain_core\runnables\base.py:2058, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    2054     child_config = patch_config(config, callbacks=run_manager.get_child())
#    2055     with set_config_context(child_config) as context:
#    2056         output = cast(
#    2057             "Output",
# -> 2058             context.run(
#    2059                 call_func_with_variable_args,  # type: ignore[arg-type]
#    2060                 func,
#    2061                 input_,
#    2062                 config,
#    2063                 run_manager,
#    2064                 **kwargs,
#    2065             ),
#    2066         )
#    2067 except BaseException as e:
#    2068     run_manager.on_chain_error(e)
#
# File d:\Projects\debyez\.venv\Lib\site-packages\langchain_core\runnables\config.py:433, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     431 if run_manager is not None and accepts_run_manager(func):
#     432     kwargs["run_manager"] = run_manager
# --> 433 return func(input, **kwargs)
#
# File d:\Projects\debyez\.venv\Lib\site-packages\langchain_core\runnables\passthrough.py:493, in RunnableAssign._invoke(self, value, run_manager, config, **kwargs)
#     488     msg = "The input to RunnablePassthrough.assign() must be a dict."
#     489     raise ValueError(msg)  # noqa: TRY004
#     491 return {
#     492     **value,
# --> 493     **self.mapper.invoke(
#     494         value,
#     495         patch_config(config, callbacks=run_manager.get_child()),
#     496         **kwargs,
#     497     ),
#     498 }
#
# File d:\Projects\debyez\.venv\Lib\site-packages\langchain_core\runnables\base.py:3867, in RunnableParallel.invoke(self, input, config, **kwargs)
#    3862     with get_executor_for_config(config) as executor:
#    3863         futures = [
#    3864             executor.submit(_invoke_step, step, input, config, key)
#    3865             for key, step in steps.items()
#    3866         ]
# -> 3867         output = {
#    3868             key: future.result()
#    3869             for key, future in zip(steps, futures, strict=False)
#    3870         }
#    3871 # finish the root run
#    3872 except BaseException as e:
#
# File d:\Projects\debyez\.venv\Lib\site-packages\langchain_core\runnables\base.py:3868, in <dictcomp>(.0)
#    3862     with get_executor_for_config(config) as executor:
#    3863         futures = [
#    3864             executor.submit(_invoke_step, step, input, config, key)
#    3865             for key, step in steps.items()
#    3866         ]
#    3867         output = {
# -> 3868             key: future.result()
#    3869             for key, future in zip(steps, futures, strict=False)
#    3870         }
#    3871 # finish the root run
#    3872 except BaseException as e:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File d:\Projects\debyez\.venv\Lib\site-packages\langchain_core\runnables\base.py:3851, in RunnableParallel.invoke.<locals>._invoke_step(step, input_, config, key)
#    3845 child_config = patch_config(
#    3846     config,
#    3847     # mark each step as a child run
#    3848     callbacks=run_manager.get_child(f"map:key:{key}"),
#    3849 )
#    3850 with set_config_context(child_config) as context:
# -> 3851     return context.run(
#    3852         step.invoke,
#    3853         input_,
#    3854         child_config,
#    3855     )
#
# File d:\Projects\debyez\.venv\Lib\site-packages\langchain_core\runnables\base.py:5548, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5541 @override
#    5542 def invoke(
#    5543     self,
#    (...)   5546     **kwargs: Any | None,
#    5547 ) -> Output:
# -> 5548     return self.bound.invoke(
#    5549         input,
#    5550         self._merge_configs(config),
#    5551         **{**self.kwargs, **kwargs},
#    5552     )
#
# File d:\Projects\debyez\.venv\Lib\site-packages\langchain_core\runnables\base.py:3143, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3141                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3142             else:
# -> 3143                 input_ = context.run(step.invoke, input_, config)
#    3144 # finish the root run
#    3145 except BaseException as e:
#
# File d:\Projects\debyez\.venv\Lib\site-packages\langchain_core\language_models\llms.py:373, in BaseLLM.invoke(self, input, config, stop, **kwargs)
#     362 @override
#     363 def invoke(
#     364     self,
#    (...)    369     **kwargs: Any,
#     370 ) -> str:
#     371     config = ensure_config(config)
#     372     return (
# --> 373         self.generate_prompt(
#     374             [self._convert_input(input)],
#     375             stop=stop,
#     376             callbacks=config.get("callbacks"),
#     377             tags=config.get("tags"),
#     378             metadata=config.get("metadata"),
#     379             run_name=config.get("run_name"),
#     380             run_id=config.pop("run_id", None),
#     381             **kwargs,
#     382         )
#     383         .generations[0][0]
#     384         .text
#     385     )
#
# File d:\Projects\debyez\.venv\Lib\site-packages\langchain_core\language_models\llms.py:784, in BaseLLM.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     775 @override
#     776 def generate_prompt(
#     777     self,
#    (...)    781     **kwargs: Any,
#     782 ) -> LLMResult:
#     783     prompt_strings = [p.to_string() for p in prompts]
# --> 784     return self.generate(prompt_strings, stop=stop, callbacks=callbacks, **kwargs)
#
# File d:\Projects\debyez\.venv\Lib\site-packages\langchain_core\language_models\llms.py:1006, in BaseLLM.generate(self, prompts, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     987 if (self.cache is None and get_llm_cache() is None) or self.cache is False:
#     988     run_managers = [
#     989         callback_manager.on_llm_start(
#     990             self._serialized,
#    (...)   1004         )
#    1005     ]
# -> 1006     return self._generate_helper(
#    1007         prompts,
#    1008         stop,
#    1009         run_managers,
#    1010         new_arg_supported=bool(new_arg_supported),
#    1011         **kwargs,
#    1012     )
#    1013 if len(missing_prompts) > 0:
#    1014     run_managers = [
#    1015         callback_managers[idx].on_llm_start(
#    1016             self._serialized,
#    (...)   1023         for idx in missing_prompt_idxs
#    1024     ]
#
# File d:\Projects\debyez\.venv\Lib\site-packages\langchain_core\language_models\llms.py:810, in BaseLLM._generate_helper(self, prompts, stop, run_managers, new_arg_supported, **kwargs)
#     799 def _generate_helper(
#     800     self,
#     801     prompts: list[str],
#    (...)    806     **kwargs: Any,
#     807 ) -> LLMResult:
#     808     try:
#     809         output = (
# --> 810             self._generate(
#     811                 prompts,
#     812                 stop=stop,
#     813                 # TODO: support multiple run managers
#     814                 run_manager=run_managers[0] if run_managers else None,
#     815                 **kwargs,
#     816             )
#     817             if new_arg_supported
#     818             else self._generate(prompts, stop=stop)
#     819         )
#     820     except BaseException as e:
#     821         for run_manager in run_managers:
#
# File d:\Projects\debyez\.venv\Lib\site-packages\langchain_ollama\llms.py:456, in OllamaLLM._generate(self, prompts, stop, run_manager, **kwargs)
#     454 generations = []
#     455 for prompt in prompts:
# --> 456     final_chunk = self._stream_with_aggregation(
#     457         prompt,
#     458         stop=stop,
#     459         run_manager=run_manager,
#     460         verbose=self.verbose,
#     461         **kwargs,
#     462     )
#     463     generations.append([final_chunk])
#     464 return LLMResult(generations=generations)
#
# File d:\Projects\debyez\.venv\Lib\site-packages\langchain_ollama\llms.py:415, in OllamaLLM._stream_with_aggregation(self, prompt, stop, run_manager, verbose, **kwargs)
#     413 final_chunk = None
#     414 thinking_content = ""
# --> 415 for stream_resp in self._create_generate_stream(prompt, stop, **kwargs):
#     416     if not isinstance(stream_resp, str):
#     417         if stream_resp.get("thinking"):
#
# File d:\Projects\debyez\.venv\Lib\site-packages\langchain_ollama\llms.py:359, in OllamaLLM._create_generate_stream(self, prompt, stop, **kwargs)
#     352 def _create_generate_stream(
#     353     self,
#     354     prompt: str,
#     355     stop: list[str] | None = None,
#     356     **kwargs: Any,
#     357 ) -> Iterator[Mapping[str, Any] | str]:
#     358     if self._client:
# --> 359         yield from self._client.generate(
#     360             **self._generate_params(prompt, stop=stop, **kwargs)
#     361         )
#
# File d:\Projects\debyez\.venv\Lib\site-packages\ollama\_client.py:179, in Client._request.<locals>.inner()
#     177 except httpx.HTTPStatusError as e:
#     178   e.response.read()
# --> 179   raise ResponseError(e.response.text, e.response.status_code) from None
#     181 for line in r.iter_lines():
#     182   part = json.loads(line)
#
# ResponseError: llama runner process has terminated: CUDA error (status code: 500)

# %%
# Run this cell to start a fresh conversation
def reset_conversation(session_id="default_session"):
    """Clear the chat history for a session."""
    if session_id in store:
        del store[session_id]
        print(f"✓ Conversation reset for session: {session_id}")
    else:
        print(f"No conversation found for session: {session_id}")


reset_conversation()
